# %%
from coinbase.wallet.client import Client

# %%
client = Client(
    api_key='',
    api_secret=''
)

# %%
import matplotlib
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
prices = pd.DataFrame(client.get_historic_prices()['prices'],
                      dtype=(np.float, np.datetime64))


prices.head()
# Out:
#      price                  time
# 0  4377.35  2017-09-05T00:00:00Z
# 1  4483.84  2017-09-04T00:00:00Z
# 2  4642.76  2017-09-03T00:00:00Z
# 3  4717.76  2017-09-02T00:00:00Z
# 4  4811.35  2017-09-01T00:00:00Z

# %%
prices.describe()
# Out:
#              price
# count   365.000000
# mean   1559.071260
# std    1053.034008
# min     596.880000
# 25%     766.200000
# 50%    1090.510000
# 75%    2351.970000
# max    4811.350000

# %% [markdown]
# It's unclear how to invest in the future.

# %%
# Buy
sorted_prices = prices.sort_values(['time'], ascending=True)
ax = sorted_prices.plot(kind='line', 
                        y='price', 
                        x='time', 
                        rot=45, 
                        style='b', 
                        figsize=(15, 5), 
                        legend=True)

# %% [markdown]
# From past data, can we label times at which should we have put in a buy or sell order? Keep in mind that each transaction cost is 3%.
# * At a BTC value of $600, the cost to buy 1 BTC is $18.  The sell price would have to be greater than ~ $648 to earn profit on the trade of one bitcoin.
# * A $60 of BTC may be a good initial investment. The sell price would have to be greater than ~$64 to earn profit initially.

# %%
# Buy
test = sorted_prices[:3]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:4]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:5]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:6]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:7]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Buy
test = sorted_prices[:8]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:9]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:10]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:11]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:12]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:13]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:14]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:15]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:16]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Buy
test = sorted_prices[:17]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:18]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:19]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:20]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:21]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:22]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:23]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:24]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:25]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:26]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:27]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:28]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:29]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:30]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:31]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:32]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:33]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:34]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:35]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:36]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:37]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:38]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:39]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:40]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:41]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:42]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:43]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Sell
test = sorted_prices[:44]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:45]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:46]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:47]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:48]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:49]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:50]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:51]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:52]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:53]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:54]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Sell
test = sorted_prices[:55]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:56]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:57]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:58]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:59]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Buy
test = sorted_prices[:60]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:61]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:62]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:63]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:64]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:65]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:66]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:67]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:68]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:69]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:70]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
# Hold
test = sorted_prices[:71]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
test = sorted_prices[:75]
test.plot(kind='line', 
          y='price', 
          x='time', 
          rot=45, 
          style='b', 
          figsize=(15, 5), 
          legend=True)

# %%
test = sorted_prices[:100]
test.describe()
# Out:
#            price
# count  100.00000
# mean   675.92140
# std     61.34069
# min    596.88000
# 25%    613.33750
# 50%    658.83500
# 75%    733.67250
# max    780.73000

# %%
test = sorted_prices[:125]
test.describe()
# Out:
#             price
# count   125.00000
# mean    721.66432
# std     114.08258
# min     596.88000
# 25%     620.97000
# 50%     710.24000
# 75%     768.29000
# max    1083.63000

# %%
test = sorted_prices[:150]
test.describe()
# Out:
#              price
# count   150.000000
# mean    750.797400
# std     124.426393
# min     596.880000
# 25%     632.847500
# 50%     733.925000
# 75%     847.942500
# max    1083.630000

# %%
test = sorted_prices[:175]
test.describe()
# Out:
#              price
# count   175.000000
# mean    795.553486
# std     160.959237
# min     596.880000
# 25%     639.720000
# 50%     755.960000
# 75%     920.275000
# max    1189.710000

# %%
test = sorted_prices[:200]
test.describe()
# Out:
#              price
# count   200.000000
# mean    842.760800
# std     198.590789
# min     596.880000
# 25%     661.372500
# 50%     779.490000
# 75%    1009.467500
# max    1281.630000

# %%
test = sorted_prices[:225]
test.describe()
# Out:
#              price
# count   225.000000
# mean    874.469956
# std     209.424760
# min     596.880000
# 25%     703.350000
# 50%     852.300000
# 75%    1035.890000
# max    1281.630000

# %%
test = sorted_prices[:250]
test.describe()
# Out:
#              price
# count   250.000000
# mean    933.128400
# std     272.931579
# min     596.880000
# 25%     710.435000
# 50%     904.070000
# 75%    1131.762500
# max    1837.420000

# %%
test = sorted_prices[:275]
test.describe()
# Out:
#              price
# count   275.000000
# mean   1051.936182
# std     467.229352
# min     596.880000
# 25%     723.590000
# 50%     930.110000
# 75%    1194.765000
# max    2833.370000

# %%
test = sorted_prices[:300]
test.describe()
# Out:
#             price
# count   300.00000
# mean   1182.04220
# std     623.47826
# min     596.88000
# 25%     734.17750
# 50%     998.56500
# 75%    1252.97250
# max    2931.42000

# %%
test = sorted_prices[:325]
test.describe()
# Out:
#              price
# count   325.000000
# mean   1280.540462
# std     692.244677
# min     596.880000
# 25%     741.550000
# 50%    1022.650000
# 75%    1591.040000
# max    2931.420000
